# %%
# Create and Write to a File
from pathlib import Path
student_id = "2025-0488"
student_name = "Khalix Julien Bocala"
documents_path = Path.home() / "Documents" /"Bocala_Activity_5"
documents_path.mkdir(parents=True, exist_ok=True)
file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name}(ID:{student_id}) to File Handling in Python!")
print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\Matienzo\Documents\Bocala_Activity_5\intro_2025-0488.txt

# %%
# Fixed Row 2: Reading the content of your specific file
from pathlib import Path

student_id = "2025-0488"

documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"intro_{student_id}.txt"

# Reading and printing the content
if file_path.exists():
    content = file_path.read_text()
    print(content)
else:
    print(f"Error: The file was not found at {file_path}")
# Out:
# Welcome Khalix Julien Bocala(ID:2025-0488) to File Handling in Python!

# %%
# Fixed Row 4: Write/Append to the correct student-specific file
from pathlib import Path

student_id = "2025-0488"
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"

file_path = documents_path / f"lines_{student_id}.txt"

with open(file_path, "a", encoding="utf-8") as file:
    file.write("Line 4: This line is being added to the correct file!\n")

print(f"Data appended successfully to: {file_path.name}")
# Out:
# Data appended successfully to: lines_2025-0488.txt

# %%
# Write Multiple Lines 
from pathlib import Path 
 
student_id = "2025-0488" 
 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
file_path = documents_path / f"lines_{student_id}.txt" 
 
lines = ["Line 1", "Line 2", "Line 3"] 
with file_path.open("w") as f: 
    f.write("\n".join(lines)) 
print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: C:\Users\Matienzo\Documents\Bocala_Activity_5\lines_2025-0488.txt

# %%
# Read File Line by Line 
from pathlib import Path 
 
student_id = "2025-0488" 
 
file_path = Path.home() / "Documents" / "Bocala_Activity_5" / f"lines_{student_id}.txt" 
 
with file_path.open("r") as f: 
    for line in f: 
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
# Count Words in File 
from pathlib import Path 
 
student_id = "2025-0488" 
student_name = "Khalix Julien Bocala" 
 
file_path = Path.home() / "Documents" / "Bocala_Activity_5" / f"lines_{student_id}.txt" 
 
text = file_path.read_text() 
word_count = len(text.split()) 
 
print(f"{student_name} (ID: {student_id}) - Word count in file '{file_path.name}': {word_count}")
# Out:
# Khalix Julien Bocala (ID: 2025-0488) - Word count in file 'lines_2025-0488.txt': 6

# %%
#Cell 1: Create and Write to a File 
from pathlib import Path 
 
student_id = "2025-0488" 
student_name = "Khalix Julien Bocala"
 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
documents_path.mkdir(parents=True, exist_ok=True) 
 
file_path = documents_path / f"intro_{student_id}.txt" 
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!") 
 
print(f"File created and text written at: {file_path}") 
 
#Cell 2: Copy File 
import shutil 
from pathlib import Path 
 
student_id = "2025-0488" 
student_name = "Khalix Julien Bocala"
 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
 
# Define source and destination 
src = documents_path / f"intro_{student_id}.txt" 
dst = documents_path / f"intro_copy_{student_id}.txt" 
 
# Copy file 
shutil.copy(src, dst) 
print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File created and text written at: C:\Users\Matienzo\Documents\Bocala_Activity_5\intro_2025-0488.txt
# File copied successfully from intro_2025-0488.txt to intro_copy_2025-0488.txt.

# %%
# Rename File 
from pathlib import Path 
 
# Personal details (keep consistent per activity) 
student_id = "2025-0488" 

 
# Define directory path 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
 
# Define old and new file paths 
old_file = documents_path /f"intro_copy_{student_id}.txt" 
new_file = documents_path /f"intro_renamed_{student_id}.txt"

# %%
# Delete File 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0488" 
 
# Define file path 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
file_path = documents_path / f"intro_renamed_{student_id}.txt" 
 
# Check and delete file if it exists 
if file_path.exists(): 
    file_path.unlink() 
    print(f"File deleted successfully from: {file_path}") 
else: 
    print(f"No file found to delete at: {file_path}")
# Out:
# File deleted successfully from: C:\Users\Matienzo\Documents\Bocala_Activity_5\intro_renamed_2025-0488.txt

# %%
# Create Directory 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0488" 
 
# Define base and new directory paths 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
new_dir = documents_path / f"data_{student_id}" 
 
# Create the new directory 
new_dir.mkdir(parents=True, exist_ok=True) 
 
print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: C:\Users\Matienzo\Documents\Bocala_Activity_5\data_2025-0488

# %%
# Write JSON File 
import json 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0488" 
# Define directory and file path 
documents_path = Path.home() / "Documents" / "Bocala_Activity_5" 
data_dir = documents_path / f"data_{student_id}" 
data_dir.mkdir(parents=True, exist_ok=True) 
 
# Sample data 
data = {"name": "Khalix Julien Bocala", "age": 18, "course": 
"Python Programming"} 
 
# Write JSON file 
file_path = data_dir / f"student_{student_id}.json" 
with file_path.open("w") as f: 
    json.dump(data, f, indent=4) 
 
print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: C:\Users\Matienzo\Documents\Bocala_Activity_5\data_2025-0488\student_2025-0488.json

# %%
# Read JSON File 
import json 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0488" 
 
# Define the path to the JSON file 
file_path = Path.home() / "Documents" / "Bocala_Activity_5" / f"data_{student_id}" / f"student_{student_id}.json" 
 
# Read and display JSON content 
with file_path.open("r") as f: 
    data = json.load(f) 
 
print(data)
# Out:
# {'name': 'Khalix Julien Bocala', 'age': 18, 'course': 'Python Programming'}

# %%
# Row 13: Write CSV File
import csv
from pathlib import Path

student_id = "2025-0488"
student_name = "Khalix Julien Bocala"

# Ensuring we use the exact folder name from your previous successful steps
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
documents_path.mkdir(parents=True, exist_ok=True)
file_path = documents_path / f"students_{student_id}.csv"

# Sample data to write
rows = [
    ["Name", "Student ID", "Score"],
    ["Joshua", "2025-1001", 90],
    ["Empoy", "2025-1002", 85],
    [student_name, student_id, 95]
]

# Write CSV file
with file_path.open("w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"CSV file created successfully at: {file_path}")
# Out:
# CSV file created successfully at: C:\Users\Matienzo\Documents\Bocala_Activity_5\students_2025-0488.csv

# %%
# Row 14: Read CSV File
import csv
from pathlib import Path

student_id = "2025-0488"
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"students_{student_id}.csv"

# Read and display CSV content
if file_path.exists():
    with file_path.open("r") as f:
        reader = csv.reader(f)
        print("CSV Content:")
        for row in reader:
            print(row)
else:
    print(f"Error: Still cannot find file at {file_path}. Ensure Row 13 finished successfully.")
# Out:
# CSV Content:
# ['Name', 'Student ID', 'Score']
# ['Joshua', '2025-1001', '90']
# ['Empoy', '2025-1002', '85']
# ['Khalix Julien Bocala', '2025-0488', '95']

# %%
# Row 15: File Not Found Handling
from pathlib import Path

# Personal details
student_id = "2025-0488"

documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"missing_file_{student_id}.txt"

# Attempt to read the file and handle error
try:
    print(file_path.read_text())
except FileNotFoundError:
    print(f"File not found for Student ID: {student_id}")
# Out:
# File not found for Student ID: 2025-0488

# %%
# Row 16: Count .txt Files
from pathlib import Path

# Personal details
student_id = "2025-0488"

documents_path = Path.home() / "Documents" / "Bocala_Activity_5"

txt_files = list(documents_path.glob("*.txt"))

# Display count and file names
print(f"Student ID: {student_id}")
print(f"Found {len(txt_files)} .txt files in {documents_path}")

for file in txt_files:
    print(file.name)
# Out:
# Student ID: 2025-0488
# Found 2 .txt files in C:\Users\Matienzo\Documents\Bocala_Activity_5
# intro_2025-0488.txt
# lines_2025-0488.txt

# %%
import os
import time
from pathlib import Path

# Personal details
student_id = "2025-0488"

# Define file path
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"intro_{student_id}.txt"

# Retrieve and display file metadata
if file_path.exists():
    stat = file_path.stat()
    print(f"Student ID: {student_id}")
    print(f"File: {file_path.name}")
    print(f"Size: {stat.st_size} bytes")
    # Convert seconds to a readable timestamp
    last_modified = time.ctime(stat.st_mtime)
    print(f"Last Modified: {last_modified}")
else:
    print(f"File {file_path.name} not found for Student ID: {student_id}")
# Out:
# Student ID: 2025-0488
# File: intro_2025-0488.txt
# Size: 72 bytes
# Last Modified: Sun May 17 18:47:02 2026

# %%
# Row 18: Uppercase and Number Lines
from pathlib import Path

# Personal details
student_id = "2025-0488"

# Define file path (ensuring consistent folder name)
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"lines_{student_id}.txt"

# Ensure file exists before reading (creating a sample if missing)
if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")

# Read, process, and rewrite the file with numbered uppercase lines
lines = file_path.read_text().splitlines()
with file_path.open("w") as f:
    for i, line in enumerate(lines, 1):
        f.write(f"{i}: {line.upper()}\n")

print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: C:\Users\Matienzo\Documents\Bocala_Activity_5\lines_2025-0488.txt

# %%
# Row 19: Reverse File Content
from pathlib import Path

# Personal details
student_id = "2025-0488"

# Define file path (using your consistent folder name)
documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
file_path = documents_path / f"lines_{student_id}.txt"

# Ensure file exists before processing
if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")

# Read, reverse, and overwrite the file
lines = file_path.read_text().splitlines()
lines.reverse()

with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: 2025-0488

# %%
# Row 20: Merge Two Files
from pathlib import Path

# Personal details
student_id = "2025-0488"

documents_path = Path.home() / "Documents" / "Bocala_Activity_5"
f1 = documents_path / f"intro_{student_id}.txt"
f2 = documents_path / f"lines_{student_id}.txt"
merged = documents_path / f"merged_{student_id}.txt"

# Ensure both source files exist
if not f1.exists():
    f1.write_text(f"Welcome {student_id} to File Handling in Python!")
    print(f"Sample intro file created for Student ID: {student_id}")

if not f2.exists():
    f2.write_text("Line 1\nLine 2\nLine 3")
    print(f"Sample lines file created for Student ID: {student_id}")

# Merge contents of both files into a new file
with merged.open("w") as mf:
    mf.write(f1.read_text())
    mf.write("\n") # Add a newline between the two files
    mf.write(f2.read_text())

print(f"Files merged successfully for Student ID: {student_id}")
print("--- Merged Content ---")
print(merged.read_text())
# Out:
# Files merged successfully for Student ID: 2025-0488
# --- Merged Content ---
# Welcome Khalix Julien Bocala (ID: 2025-0488) to File Handling in Python!
# 3: LINE 3
# 2: LINE 2
# 1: LINE 1
