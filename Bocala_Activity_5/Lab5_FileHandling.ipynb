# %%
# Step 1: Import Path from pathlib
from pathlib import Path
# Step 2: Define a custom folder in your Documents directory
output_dir = Path.home() / "Documents" / "Bocala_Activity_5"
output_dir.mkdir(exist_ok=True) # Creates folder if missing
# Step 3: Define the file path
file_path = output_dir / "Act5_example.txt"
# Step 4: Write text to the file
with open(file_path, "w", encoding="utf-8") as file:
 file.write("Hello, Welcome to Python Programming!\n")
 file.write("File saved safely with pathlib.")
 file.write("Python makes file handling easy!")

# Step 5: Confirm that the file is saved
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\Matienzo\Documents\Bocala_Activity_5\Act5_example.txt

# %%
# Step 1: Read the entire file content if it exists
if file_path.exists():
 with open(file_path, "r", encoding="utf-8") as file:
   content = file.read()
print("File content:\n", content)
# Step 2: Read line-by-line
with open(file_path, "r", encoding="utf-8") as file:
  for line_number, line in enumerate(file, 1): 
   print(f"Line {line_number}: {line.strip()}")
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.Python makes file handling easy!
# Line 1: Hello, Welcome to Python Programming!
# Line 2: File saved safely with pathlib.Python makes file handling easy!

# %%
# Step 1: Open file in append mode
with open(file_path, "a", encoding="utf-8") as file:
 file.write("\nThis line was added!")
# Step 2: Confirm that data was added
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
# Step 1: Import additional libraries
from datetime import datetime
import shutil
# Step 2: Define working directory
backup_dir = Path.home() / "Documents" / "Bocala_Activity_5"
backup_dir.mkdir(exist_ok=True)
# Step 3: Define a function to write a file with backup
def write_with_backup(filename: str, content: str):
 file_path = backup_dir / filename
 # Create backup if file exists
 if file_path.exists():
  timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
  backup_path = file_path.with_name(f"{file_path.stem}_backup_{timestamp}{file_path.suffix}")
  shutil.copy2(file_path, backup_path)
  print(f"Backup saved: {backup_path.name}")
 # Write the new content
with open(file_path, "w", encoding="utf-8") as file:
 file.write(content)
 print(f"File saved: {file_path.name}")
# Step 4: Define a function to read the file content
def read_file(filename: str):
 file_path = backup_dir / filename
 with open(file_path, "r", encoding="utf-8") as file:
    content = file.read()
 return content
# Step 5: Run demonstration
print("=== File Operations Demo ===")
print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")
print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")
print("\n3. Reading file:")
print(read_file("demo.txt"))
print("\n4. Listing backups:")
for backup in backup_dir.glob("*backup*"):
 print("-", backup.name)
# Out:
# File saved: Act5_example.txt
# === File Operations Demo ===
#
# 1. Creating new file:
#
# 2. Updating file (with backup):
#
# 3. Reading file:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 33
#      31 write_with_backup("demo.txt", "Updated content")
#      32 print("\n3. Reading file:")
# ---> 33 print(read_file("demo.txt"))
#      34 print("\n4. Listing backups:")
#      35 for backup in backup_dir.glob("*backup*"):
#
# Cell In[7], line 23, in read_file(filename)
#      21 def read_file(filename: str):
#      22  file_path = backup_dir / filename
# ---> 23  with open(file_path, "r", encoding="utf-8") as file:
#      24     content = file.read()
#      25  return content
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Matienzo\\Documents\\Bocala_Activity_5\\demo.txt'

# %%
# Step 1: Import required modules
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "Bocala_Activity_5"
backup_dir.mkdir(parents=True, exist_ok=True) 

def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = backup_dir / file_name
    
    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")
        
        choice = input("Choose an option (1-5): ")
        
        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")
            
        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")
            
        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")
                
        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")
                
        elif choice == "5":
            print("Exiting the file manager.")
            break
            
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 61
#      58             print("Invalid choice. Please try again.")
#      60 if __name__ == "__main__":
# ---> 61     file_manager()
#
# Cell In[9], line 25, in file_manager()
#      23 if choice == "1":
#      24     content = input("Enter content to write:\n")
# ---> 25     with open(file_path, "w", encoding="utf-8") as f:
#      26         f.write(content)
#      27     print("File written successfully.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Matienzo\\Documents\\Bocala_Activity_5'
